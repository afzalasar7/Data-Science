# %% [markdown]
# <a href="https://colab.research.google.com/github/afzalasar7/Data-Science/blob/main/Week%2013%20EDA/EDA_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Flight Price:

# %% [markdown]
# # Q1: Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
import pandas as pd

# Load the dataset
df = pd.read_excel("flight_price.xlsx")

# Check dimensions
num_rows, num_cols = df.shape
print("Number of Rows:", num_rows)
print("Number of Columns:", num_cols)
# Out:
# Number of Rows: 10683
# Number of Columns: 11

# %% [markdown]
# # Q2: What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.

# %%
import matplotlib.pyplot as plt

# Create a histogram
plt.hist(df['Price'], bins=20, edgecolor='k')
plt.xlabel('Flight Price')
plt.ylabel('Frequency')
plt.title('Distribution of Flight Prices')
plt.show()


price_range = df['Price'].max() - df['Price'].min()
min_price = df['Price'].min()
max_price = df['Price'].max()

print("Price Range:", price_range)
print("Minimum Price:", min_price)
print("Maximum Price:", max_price)
# Out:
# Price Range: 77753
# Minimum Price: 1759
# Maximum Price: 79512

# %% [markdown]
# # Q3: What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
price_range = df['Price'].max() - df['Price'].min()
min_price = df['Price'].min()
max_price = df['Price'].max()

print("Price Range:", price_range)
print("Minimum Price:", min_price)
print("Maximum Price:", max_price)
# Out:
# Price Range: 77753
# Minimum Price: 1759
# Maximum Price: 79512

# %% [markdown]
# # Q4: How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.

# %%
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Airline', y='Price')
plt.xticks(rotation=45)
plt.xlabel('Airline')
plt.ylabel('Flight Price')
plt.title('Flight Prices by Airline')
plt.show()

# %% [markdown]
# # Q5: Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how they may impact your analysis.

# %%
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Airline', y='Price')
plt.xticks(rotation=45)
plt.xlabel('Airline')
plt.ylabel('Flight Price')
plt.title('Flight Prices by Airline')
plt.show()

# %% [markdown]
# Outliers may impact your analysis by skewing the distribution, affecting statistical measures, and potentially leading to biased insights.

# %% [markdown]
# # Q6: You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_excel("flight_price.xlsx")

# Extract month from 'Date_of_Journey'
df['Journey_Month'] = pd.to_datetime(df['Date_of_Journey']).dt.month

# Analyze average prices by month
avg_prices_by_month = df.groupby('Journey_Month')['Price'].mean()

# Plotting average prices by month
plt.figure(figsize=(10, 5))
sns.barplot(x=avg_prices_by_month.index, y=avg_prices_by_month.values)
plt.xlabel('Month')
plt.ylabel('Average Price')
plt.title('Average Flight Prices by Month')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()
# Out:
# <ipython-input-113-7e4fbb7f44ba>:9: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Journey_Month'] = pd.to_datetime(df['Date_of_Journey']).dt.month

# %% [markdown]
# # Q7: You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify any trends in flight prices. What features would you analyze to identify these trends, and what visualizations would you use to present your findings to your team?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_excel("flight_price.xlsx")

# Convert 'Date_of_Journey' to datetime
df['Date_of_Journey'] = pd.to_datetime(df['Date_of_Journey'])

# Analyze trends using line plot
plt.figure(figsize=(12, 6))
sns.lineplot(x='Date_of_Journey', y='Price', data=df)
plt.xlabel('Date of Journey')
plt.ylabel('Price')
plt.title('Flight Price Trends')
plt.show()
# Out:
# <ipython-input-114-534215c60770>:9: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date_of_Journey'] = pd.to_datetime(df['Date_of_Journey'])

# %% [markdown]
# # Q8: You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you present your findings to the management team?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_excel("flight_price.xlsx")

# Analyze average prices by airline
avg_prices_by_airline = df.groupby('Airline')['Price'].mean().sort_values(ascending=False)

# Plotting average prices by airline
plt.figure(figsize=(10, 6))
sns.barplot(x=avg_prices_by_airline.index, y=avg_prices_by_airline.values)
plt.xlabel('Airline')
plt.ylabel('Average Price')
plt.title('Average Flight Prices by Airline')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Google Playstore:

# %%
import pandas as pd

# Load the Google Playstore dataset
url = 'https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv'
df = pd.read_csv(url)
df_copy = df.copy()

# %%
df_copy=df_copy.drop(df.index[10472])
df=df.drop(df.index[10472])
chars_to_remove=['+',',','$']
cols_to_clean=['Installs','Price']
for item in chars_to_remove:
    for cols in cols_to_clean:
        df_copy[cols]=df_copy[cols].str.replace(item,'')
# Out:
# <ipython-input-117-72fac172f663>:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_copy[cols]=df_copy[cols].str.replace(item,'')

# %%
df_copy['Installs']=df_copy['Installs'].astype('int')
df_copy['Price']=df_copy['Price'].astype('float')

# %% [markdown]
# # Q9: Load the Google Playstore dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
rows, columns = df.shape
print("Number of rows:", rows)
print("Number of columns:", columns)
# Out:
# Number of rows: 10840
# Number of columns: 13

# %% [markdown]
# # Q10: How does the rating of apps vary by category? Create a boxplot to compare the ratings of different app categories.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.boxplot(x='Category', y='Rating', data=df)
plt.xticks(rotation=90)
plt.title("Rating Variation by Category")
plt.show()

# %% [markdown]
# # Q11: Are there any missing values in the dataset? Identify any missing values and describe how they may impact your analysis.

# %%
missing_values = df.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# Outliers may impact your analysis by skewing the distribution, affecting statistical measures, and potentially leading to biased insights.

# %% [markdown]
# # Q12: What is the relationship between the size of an app and its rating? Create a scatter plot to visualize the relationship.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Size', y='Rating', data=df)
plt.title("Size vs. Rating")
plt.xlabel("Size")
plt.ylabel("Rating")
plt.show()

# %% [markdown]
# # Q13: How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
plt.figure(figsize=(8, 5))
df['Price'] = df['Price'].str.replace('$', '').astype(float)
average_prices_by_type = df.groupby('Type')['Price'].mean()
average_prices_by_type.plot(kind='bar')
plt.title("Average Prices by App Type")
plt.ylabel("Average Price")
plt.show()
# Out:
# <ipython-input-123-577651e4a447>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Price'] = df['Price'].str.replace('$', '').astype(float)

# %% [markdown]
# # Q14: What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps with the highest number of installs.

# %%
top_10_apps = df_copy.nlargest(10, 'Installs')[['App', 'Installs']]
print("Top 10 Most Popular Apps:\n", top_10_apps)
# Out:
# Top 10 Most Popular Apps:
#                                            App    Installs
# 152                         Google Play Books  1000000000
# 335  Messenger – Text and Video Chat for Free  1000000000
# 336                        WhatsApp Messenger  1000000000
# 338              Google Chrome: Fast & Secure  1000000000
# 340                                     Gmail  1000000000
# 341                                  Hangouts  1000000000
# 381                        WhatsApp Messenger  1000000000
# 382  Messenger – Text and Video Chat for Free  1000000000
# 386                                  Hangouts  1000000000
# 391             Skype - free IM & video calls  1000000000

# %% [markdown]
# # Q15: A company wants to launch a new app on the Google Playstore and has asked you to analyze the Google Playstore dataset to identify the most popular app categories. How would you approach this task, and what features would you analyze to make recommendations to the company?

# %%
popular_categories = df.groupby('Category')['Installs'].sum().sort_values(ascending=False)
print("Most Popular App Categories:\n", popular_categories.head())
# Out:
# Most Popular App Categories:
#  Category
# PRODUCTIVITY       500,000,000+10,000,000+100,000,000+10,000,000+...
# BEAUTY             500,000+1,000,000+100,000+500,000+1,000,000+50...
# FAMILY             50,000,000+10,000,000+100,000,000+1,000,000+5,...
# WEATHER            50,000,000+1,000,000+50,000,000+10,000+10,000,...
# PERSONALIZATION    50,000,000+1,000,000+100,000,000+5,000,000+100...
# Name: Installs, dtype: object

# %% [markdown]
# # Q16: A mobile app development company wants to analyze the Google Playstore dataset to identify the most successful app developers. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')

# Group by app and calculate total installs
app_data = df.groupby('App')['Installs'].sum()

# Sort apps by total installs
top_apps = app_data.sort_values(ascending=False).head(10)

# Data visualization
plt.figure(figsize=(10, 6))
plt.barh(top_apps.index, top_apps.values, color='skyblue')
plt.xlabel('Total Installs')
plt.ylabel('Apps')
plt.title('Top 10 Most Successful Apps')
plt.gca().invert_yaxis()  # Invert y-axis for descending order
plt.show()

# %%
developer_performance = df.groupby('Category')['Installs'].sum().sort_values(ascending=False)
print("Most Successful App Developers:\n", developer_performance.head())
# Out:
# Most Successful App Developers:
#  Category
# 1.9                                                          Free
# PRODUCTIVITY    500,000,000+10,000,000+100,000,000+10,000,000+...
# BEAUTY          500,000+1,000,000+100,000+500,000+1,000,000+50...
# FAMILY          50,000,000+10,000,000+100,000,000+1,000,000+5,...
# WEATHER         50,000,000+1,000,000+50,000,000+10,000+10,000,...
# Name: Installs, dtype: object

# %% [markdown]
# # Q17: A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to launch a new app. What features would you analyze to make recommendations to the company, and what data visualizations would you use to present your findings?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
url = 'https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv'
df = pd.read_csv(url)

df_copy['Last Updated']=pd.to_datetime(df_copy['Last Updated'])
df_copy['Day']=df_copy['Last Updated'].dt.day
df_copy['Month']=df_copy['Last Updated'].dt.month
df_copy['Year']=df_copy['Last Updated'].dt.year
# Calculate the average rating by month
avg_rating_by_month = df_copy.groupby('Month')['Rating'].mean()

# Visualize the average rating by month
plt.figure(figsize=(10, 6))
sns.lineplot(x=avg_rating_by_month.index, y=avg_rating_by_month.values)
plt.title('Average Rating by Month')
plt.xlabel('Month')
plt.ylabel('Average Rating')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()
